# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.asarray(["Moscow", "Saint-Peterburg", "Ekaterinburg", "Kazan"])
y = np.random.randint(100, 500, size = 4)

fig, ax = plt.subplots()

ax.bar(x, y)

ax.set_facecolor('seashell')
fig.set_facecolor('floralwhite')
fig.set_figwidth(6)    
fig.set_figheight(2)    


plt.show()

# %%
# Import libraries
import numpy as np
import matplotlib.pyplot as plt


# Creating dataset
skills = ['Python', 'C++', 'Pandas', 'Numpy', 'JavaScript']

data = np.random.randint(100, 500, size = 5)


# Creating explode data
explode = (0.1, 0.0, 0.2, 0.3, 0.0)

# Creating color parameters
colors = ( "orange", "cyan", "brown",
		"grey", "indigo")

# Wedge properties
wp = { 'linewidth' : 1, 'edgecolor' : "green" }

# Creating autocpt arguments
def func(pct, allvalues):
	absolute = int(pct / 100.*np.sum(allvalues))
	return "{:.1f}%\n({:d})".format(pct, absolute)

# Creating plot
fig, ax = plt.subplots(figsize =(6, 5))
wedges, texts, autotexts = ax.pie(data,
								autopct = lambda pct: func(pct, data),
								explode = explode,
								labels = skills,
								shadow = True,
								colors = colors,
								startangle = 90,
								wedgeprops = wp,
								textprops = dict(color ="magenta"))

# Adding legend
ax.legend(wedges, skills,
		title ="Навыки",
		loc ="center left",
		bbox_to_anchor =(1, 0, 0.5, 1))

plt.setp(autotexts, size = 7, weight ="bold")
ax.set_title("Ключевые навыки")

# show plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np 

  
# Creating dataset 
np.random.seed(10) 
data_1 = np.random.normal(100, 10, 200) 
data_2 = np.random.normal(90, 20, 200) 
data_3 = np.random.normal(80, 30, 200) 
plt.boxplot([data_1, data_2, data_3], 
            notch=None, 
            vert=None, 
            patch_artist=None, 
            widths=None, 
            labels = ["Python-разработчик", "Аналитик", "ML-разработчик"])
plt.title("max, min и наиболее вероятная з/п")

plt.show()

# %%
k = np.random.normal(100, 10, 200) 
k.mean(), k, len(k)
# Out:
# (100.77794078006623,
#  array([111.0255236 , 104.10938417, 111.99534335, 104.78689254,
#         107.84998876,  95.6771665 ,  95.17252583,  90.1857452 ,
#         107.24829791,  94.37013945,  96.8518271 ,  97.34862228,
#          98.02514375,  76.23242222,  88.2370096 , 104.30650994,
#          82.34406749, 112.14113551, 104.55770106,  94.66826927,
#          98.79562251,  98.80944756, 106.99300068, 103.19170243,
#         111.38441683, 115.76845493, 111.51643704,  97.84480617,
#         105.11345948, 100.36531007, 106.04657248,  74.98688994,
#          84.04242358, 124.56307823, 104.76423981, 115.41533379,
#         111.08330504,  93.87178303,  94.27271076, 102.74775113,
#         100.7118537 ,  89.05064014,  82.91114916, 105.69146243,
#         109.38668093,  84.53614994,  99.73294218, 122.06561866,
#          93.59267057, 100.84735828, 101.47581054, 114.63523354,
#          94.53964192,  89.84579091, 117.39767092, 105.47325697,
# ...
